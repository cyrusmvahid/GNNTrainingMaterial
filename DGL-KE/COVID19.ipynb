# %% [markdown]
#    # Drug Repurposing

# %%
# !conda install -c conda-forge rise
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/miniconda3/envs/dgl-torch
#
#   added / updated specs:
#     - rise
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appnope-0.1.0              |py38h32f6830_1001           9 KB  conda-forge
#     attrs-19.3.0               |             py_0          35 KB  conda-forge
#     backcall-0.1.0             |             py_0          13 KB  conda-forge
#     bleach-3.1.5               |     pyh9f0ad1d_0         112 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     certifi-2020.4.5.1         |   py38h32f6830_0         151 KB  conda-forge
# ...
